# %%
 # Import
import pandas as pd
import numpy as np
df = pd.read_csv("data/All_Data_Aldi.csv")

 # Checking values
df.shape
# Out:
# (464863, 8)

# %%
 # Checking for NULL values (Run again to test)
df.isnull().sum()
# Out:
# supermarket        0
# prices_(£)         0
# prices_unit_(£)    4
# unit               4
# names              0
# date               0
# category           0
# own_brand          0
# dtype: int64

# %%
 # Deleting NULL values
df = df.dropna()

# %% [markdown]
# **CHECKING** largest and smallest values

# %%
df.nlargest(10, "prices_unit_(£)")
# Out:
#        supermarket  prices_(£)  prices_unit_(£) unit  \
# 154143        Aldi        3.75           2343.8   kg
# 154144        Aldi        3.75           2343.8   kg
# 158287        Aldi        3.75           2343.8   kg
# 158290        Aldi        3.75           2343.8   kg
# 163802        Aldi        3.75           2343.8   kg
# 164185        Aldi        3.75           2343.8   kg
# 172538        Aldi        3.75           2343.8   kg
# 172542        Aldi        3.75           2343.8   kg
# 175924        Aldi        3.75           2343.8   kg
# 175928        Aldi        3.75           2343.8   kg
#
#                                        names      date       category  \
# 154143   Heinz Cream Of Tomato Soup 4 X 400g  20240313  food_cupboard
# 154144  Heinz Cream Of Chicken Soup 4 X 400g  20240313  food_cupboard
# 158287   Heinz Cream Of Tomato Soup 4 X 400g  20240312  food_cupboard
# 158290  Heinz Cream Of Chicken Soup 4 X 400g  20240312  food_cupboard
# 163802  Heinz Cream Of Chicken Soup 4 X 400g  20240311  food_cupboard
# 164185   Heinz Cream Of Tomato Soup 4 X 400g  20240311  food_cupboard
# 172538   Heinz Cream Of Tomato Soup 4 X 400g  20240310  food_cupboard
# 172542  Heinz Cream Of Chicken Soup 4 X 400g  20240310  food_cupboard
# 175924   Heinz Cream Of Tomato Soup 4 X 400g  20240309  food_cupboard
# 175928  Heinz Cream Of Chicken Soup 4 X 400g  20240309  food_cupboard
#
#         own_brand
# 154143      False
# 154144      False
# 158287      False
# 158290      False
# 163802      False
# 164185      False
# 172538      False
# 172542      False
# 175924      False
# 175928      False

# %%
df.nsmallest(10, "prices_unit_(£)")
# Out:
#      supermarket  prices_(£)  prices_unit_(£)  unit  \
# 1802        Aldi        1.79              0.0  unit
# 1803        Aldi        2.69              0.0  unit
# 1804        Aldi        4.99              0.0  unit
# 1805        Aldi        5.29              0.0  unit
# 1806        Aldi        1.29              0.0  unit
# 1807        Aldi        5.29              0.0  unit
# 1808        Aldi        2.69              0.0  unit
# 1809        Aldi        2.69              0.0  unit
# 1810        Aldi        4.99              0.0  unit
# 1811        Aldi        2.55              0.0  unit
#
#                                                names      date   category  \
# 1802            Saxon Standard Toilet Tissue 4 Rolls  20240413  household
# 1803              Saxon Quilted Toilet Tissue 4 Pack  20240413  household
# 1804    Saxon Softest Premium Toilet Tissue 12 Rolls  20240413  household
# 1805   Saxon Softest Aloe Vera Toilet Tissue 8 Rolls  20240413  household
# 1806              Saxon Luxury Toilet Tissue 2 Rolls  20240413  household
# 1807              Saxon Quilted Toilet Tissue 8 Pack  20240413  household
# 1808    Saxon Softest Aloe Vera Toilet Tissue 4 Pack  20240413  household
# 1809  Saxon Softest Coconut Oil Toilet Tissue 4 Pack  20240413  household
# 1810    Saxon Softest Premium Toilet Tissue 24 Rolls  20240413  household
# 1811              Saxon Luxury Toilet Tissue 4 Rolls  20240413  household
#
#       own_brand
# 1802      False
# 1803      False
# 1804      False
# 1805      False
# 1806      False
# 1807      False
# 1808      False
# 1809      False
# 1810      False
# 1811      False

# %%
 #Quick anomaly check
df["prices_unit_(£)"].describe()
# Out:
# count    464859.000000
# mean          7.993101
# std          41.288759
# min           0.000000
# 25%           2.230000
# 50%           5.300000
# 75%           9.000000
# max        2343.800000
# Name: prices_unit_(£), dtype: float64

# %% [markdown]
# **CLEANING DATA**

# %%
# REMOVING values below 0

df = df[(df["prices_(£)"] > 0)]

# %% [markdown]
# FILTERING PRICES above/ below 50%

# %%
# Sorting values and getting previous product price
df = df.sort_values(["names", "date"])

df["previous_price"] = df.groupby("names")["prices_(£)"].shift(1)

df["previous_price"]
# Out:
# 380250     NaN
# 380388     NaN
# 378689     NaN
# 378547     NaN
# 378975     NaN
#           ...
# 25035     1.19
# 16971     1.19
# 13010     1.19
# 5854      1.19
# 3612      1.19
# Name: previous_price, Length: 464859, dtype: float64

# %%
# Price change calculator (Percentage)

df["price_change"] = df["prices_(£)"] - df["previous_price"]

df["percent_change"] = (
    (df["prices_(£)"] - df["previous_price"])
    / df["previous_price"]
) * 100

df.sort_values(by="percent_change", ascending=False)
# Out:
#        supermarket  prices_(£)  prices_unit_(£) unit  \
# 68632         Aldi        0.89             3.60   kg
# 32631         Aldi        0.89             3.60   kg
# 9652          Aldi      383.00           806.32   kg
# 65308         Aldi        1.39             0.70   kg
# 67725         Aldi        2.15             7.40    l
# ...            ...         ...              ...  ...
# 36431         Aldi        0.65             1.30    l
# 215445        Aldi        0.99             3.00    l
# 381043        Aldi        1.49             3.39    l
# 376458        Aldi        1.49             3.39    l
# 460969        Aldi        1.19             2.38    l
#
#                                                     names      date  \
# 68632                    Bramwells Bacon Mayonnaise 250ml  20240331
# 32631           Bramwells Lemon & Black Pepper Mayo 250ml  20240407
# 9652               Ashfields 100% British Lamb Mince 475g  20240412
# 65308                          Nature's Pick Potatoes 2kg  20240401
# 67725         Specially Selected Raspberry Lollies 4x73ml  20240331
# ...                                                   ...       ...
# 36431                    Älska Cherry Premium Cider 500ml  20240406
# 215445  Älska Limited Edition Blueberry Lemonade Premi...  20240301
# 381043   Älska Nordic Berries Premium Swedish Cider 440ml  20240126
# 376458  Älska Strawberry & Lime Premium Swedish Cider ...  20240126
# 460969    Älska The Swedish Cider Strawberry & Lime 500ml  20240109
#
#              category  own_brand  previous_price  price_change  percent_change
# 68632   food_cupboard      False            0.01          0.88     8800.000000
# 32631   food_cupboard      False            0.01          0.88     8800.000000
# 9652       fresh_food      False            4.39        378.61     8624.373576
# 65308      fresh_food      False            0.15          1.24      826.666667
# 67725          frozen       True            0.29          1.86      641.379310
# ...               ...        ...             ...           ...             ...
# 36431       free-from      False             NaN           NaN             NaN
# 215445         drinks      False             NaN           NaN             NaN
# 381043         drinks      False             NaN           NaN             NaN
# 376458         drinks      False             NaN           NaN             NaN
# 460969         drinks      False             NaN           NaN             NaN
#
# [464859 rows x 11 columns]

# %%
 # Checking for NA values 
 df.isnull().sum()
# Out:
# supermarket           0
# prices_(£)            0
# prices_unit_(£)       0
# unit                  0
# names                 0
# date                  0
# category              0
# own_brand             0
# previous_price     7261
# price_change       7261
# percent_change     7261
# dtype: int64

# %%
 #Dropping NA values again
df = df.dropna()

# %%
 # Finding suspicious values 
suspicious = df[df["percent_change"].abs() > 50]

suspicious.sort_values(by='percent_change', ascending=True)
# Out:
#        supermarket  prices_(£)  prices_unit_(£) unit  \
# 102701        Aldi        0.01             0.00    l
# 102253        Aldi        0.01             0.00    l
# 97575         Aldi        0.15             0.08   kg
# 64962         Aldi        0.49             5.80   kg
# 64969         Aldi        0.49             5.80   kg
# ...            ...         ...              ...  ...
# 67726         Aldi        2.15             7.40    l
# 65308         Aldi        1.39             0.70   kg
# 9652          Aldi      383.00           806.32   kg
# 32631         Aldi        0.89             3.60   kg
# 68632         Aldi        0.89             3.60   kg
#
#                                                     names      date  \
# 102701          Bramwells Lemon & Black Pepper Mayo 250ml  20240325
# 102253                   Bramwells Bacon Mayonnaise 250ml  20240325
# 97575                          Nature's Pick Potatoes 2kg  20240326
# 64962   Dairyfine Strawberry Flavour & White Choco Lun...  20240401
# 64969         Dairyfine Orange Choco Bertie The Bunny 85g  20240401
# ...                                                   ...       ...
# 67726           Specially Selected Coconut Lollies 4x73ml  20240331
# 65308                          Nature's Pick Potatoes 2kg  20240401
# 9652               Ashfields 100% British Lamb Mince 475g  20240412
# 32631           Bramwells Lemon & Black Pepper Mayo 250ml  20240407
# 68632                    Bramwells Bacon Mayonnaise 250ml  20240331
#
#              category  own_brand  previous_price  price_change  percent_change
# 102701  food_cupboard      False            0.19         -0.18      -94.736842
# 102253  food_cupboard      False            0.19         -0.18      -94.736842
# 97575      fresh_food      False            1.39         -1.24      -89.208633
# 64962   food_cupboard      False            2.99         -2.50      -83.612040
# 64969   food_cupboard      False            2.99         -2.50      -83.612040
# ...               ...        ...             ...           ...             ...
# 67726          frozen       True            0.29          1.86      641.379310
# 65308      fresh_food      False            0.15          1.24      826.666667
# 9652       fresh_food      False            4.39        378.61     8624.373576
# 32631   food_cupboard      False            0.01          0.88     8800.000000
# 68632   food_cupboard      False            0.01          0.88     8800.000000
#
# [293 rows x 11 columns]

# %%
df.shape #quick check
# Out:
# (457598, 11)

# %%
 # REMOVING suspicious values 
suspicious = df[df["percent_change"].abs() > 50]

df = df[df["percent_change"].abs() <= 50]

# %%
df.shape #quick result check
# Out:
# (457305, 11)

# %% [markdown]
# **REMOVING** prices_unit

# %%
  # Defining the medium
df["median_price_unit"] = (
    df.groupby("names")["prices_unit_(£)"]
      .transform("median")
)

 # Finding the % of medium 
df["percent_difference"] = (
    abs(df["prices_unit_(£)"] - df["median_price_unit"])
    / df["median_price_unit"]
) * 100

suspicious2 = df[df["percent_difference"] > 100]

suspicious2.sort_values("percent_difference", ascending=False)
# Out:
#        supermarket  prices_(£)  prices_unit_(£) unit  \
# 459038        Aldi        1.05             2.10   kg
# 98510         Aldi        0.95             1.90   kg
# 93983         Aldi        0.95             1.90   kg
# 83967         Aldi        0.95             1.90   kg
# 81699         Aldi        0.95             1.90   kg
# ...            ...         ...              ...  ...
# 52055         Aldi       19.99            26.59    l
# 50764         Aldi       19.99            26.59    l
# 52056         Aldi       19.99            26.59    l
# 60993         Aldi       19.99            26.59    l
# 60992         Aldi       19.99            26.59    l
#
#                                                     names      date category  \
# 459038                               Earls Crunchies 500g  20240110     pets
# 98510                                Earls Crunchies 500g  20240326     pets
# 93983                                Earls Crunchies 500g  20240327     pets
# 83967                                Earls Crunchies 500g  20240328     pets
# 81699                                Earls Crunchies 500g  20240329     pets
# ...                                                   ...       ...      ...
# 52055                       Louis Chevallier Chablis 75cl  20240403   drinks
# 50764   Saint Emilion Grand Cru Chateau Guillemin La G...  20240404   drinks
# 52056   Saint Emilion Grand Cru Chateau Guillemin La G...  20240403   drinks
# 60993   Saint Emilion Grand Cru Chateau Guillemin La G...  20240402   drinks
# 60992                       Louis Chevallier Chablis 75cl  20240402   drinks
#
#         own_brand  previous_price  price_change  percent_change  \
# 459038      False            1.05           0.0             0.0
# 98510       False            0.95           0.0             0.0
# 93983       False            0.95           0.0             0.0
# 83967       False            0.95           0.0             0.0
# 81699       False            0.95           0.0             0.0
# ...           ...             ...           ...             ...
# 52055       False           19.99           0.0             0.0
# 50764       False           19.99           0.0             0.0
# 52056       False           19.99           0.0             0.0
# 60993       False           19.99           0.0             0.0
# 60992       False           19.99           0.0             0.0
#
#         median_price_unit  percent_difference
# 459038               0.00                 inf
# 98510                0.00                 inf
# 93983                0.00                 inf
# 83967                0.00                 inf
# 81699                0.00                 inf
# ...                   ...                 ...
# 52055               13.29          100.075245
# 50764               13.29          100.075245
# 52056               13.29          100.075245
# 60993               13.29          100.075245
# 60992               13.29          100.075245
#
# [2522 rows x 13 columns]

# %%
 # Removes values above 100
df = df[df["percent_difference"] <= 100]

# %%
 # Quick anomaly check
df.nlargest(10, "prices_(£)")
# Out:
#        supermarket  prices_(£)  prices_unit_(£) unit  \
# 210591        Aldi       35.23            14.99   kg
# 208796        Aldi       35.23            14.99   kg
# 199931        Aldi       35.23            14.99   kg
# 195920        Aldi       35.23            14.99   kg
# 191611        Aldi       35.23            14.99   kg
# 188439        Aldi       35.23            14.99   kg
# 181287        Aldi       35.23            14.99   kg
# 174561        Aldi       35.23            14.99   kg
# 170834        Aldi       35.23            14.99   kg
# 165957        Aldi       35.23            14.99   kg
#
#                                                     names      date  \
# 210591  Specially Selected 2 Bone Rib Of Beef With Sea...  20240302
# 208796  Specially Selected 2 Bone Rib Of Beef With Sea...  20240303
# 199931  Specially Selected 2 Bone Rib Of Beef With Sea...  20240304
# 195920  Specially Selected 2 Bone Rib Of Beef With Sea...  20240305
# 191611  Specially Selected 2 Bone Rib Of Beef With Sea...  20240306
# 188439  Specially Selected 2 Bone Rib Of Beef With Sea...  20240307
# 181287  Specially Selected 2 Bone Rib Of Beef With Sea...  20240308
# 174561  Specially Selected 2 Bone Rib Of Beef With Sea...  20240309
# 170834  Specially Selected 2 Bone Rib Of Beef With Sea...  20240310
# 165957  Specially Selected 2 Bone Rib Of Beef With Sea...  20240311
#
#           category  own_brand  previous_price  price_change  percent_change  \
# 210591  fresh_food       True           35.23           0.0             0.0
# 208796  fresh_food       True           35.23           0.0             0.0
# 199931  fresh_food       True           35.23           0.0             0.0
# 195920  fresh_food       True           35.23           0.0             0.0
# 191611  fresh_food       True           35.23           0.0             0.0
# 188439  fresh_food       True           35.23           0.0             0.0
# 181287  fresh_food       True           35.23           0.0             0.0
# 174561  fresh_food       True           35.23           0.0             0.0
# 170834  fresh_food       True           35.23           0.0             0.0
# 165957  fresh_food       True           35.23           0.0             0.0
#
#         median_price_unit  percent_difference
# 210591              14.99                 0.0
# 208796              14.99                 0.0
# 199931              14.99                 0.0
# 195920              14.99                 0.0
# 191611              14.99                 0.0
# 188439              14.99                 0.0
# 181287              14.99                 0.0
# 174561              14.99                 0.0
# 170834              14.99                 0.0
# 165957              14.99                 0.0

# %% [markdown]
# **REMOVING** 0.0 values

# %%
df.shape #quick check
# Out:
# (452737, 13)

# %%
 #Removing values
df = df[(df["prices_unit_(£)"] > 0.1) & (df["prices_unit_(£)"] < 100)]

# %%
df.shape #quick check
# Out:
# (440662, 13)

# %% [markdown]
# FINAL CHECK FOR ANOMALIES

# %%
df.nsmallest(10, "prices_unit_(£)")
# Out:
#        supermarket  prices_(£)  prices_unit_(£)  unit  \
# 460062        Aldi         3.5             0.11  unit
# 452062        Aldi         3.5             0.11  unit
# 447885        Aldi         3.5             0.11  unit
# 443000        Aldi         3.5             0.11  unit
# 438363        Aldi         3.5             0.11  unit
# 433144        Aldi         3.5             0.11  unit
# 427865        Aldi         3.5             0.11  unit
# 422294        Aldi         3.5             0.11  unit
# 403510        Aldi         3.5             0.11  unit
# 399915        Aldi         3.5             0.11  unit
#
#                                                     names      date  \
# 460062  Always Ultra Day Sanitary Towels Normal (Size ...  20240110
# 452062  Always Ultra Day Sanitary Towels Normal (Size ...  20240111
# 447885  Always Ultra Day Sanitary Towels Normal (Size ...  20240112
# 443000  Always Ultra Day Sanitary Towels Normal (Size ...  20240113
# 438363  Always Ultra Day Sanitary Towels Normal (Size ...  20240114
# 433144  Always Ultra Day Sanitary Towels Normal (Size ...  20240115
# 427865  Always Ultra Day Sanitary Towels Normal (Size ...  20240116
# 422294  Always Ultra Day Sanitary Towels Normal (Size ...  20240117
# 403510  Always Ultra Day Sanitary Towels Normal (Size ...  20240121
# 399915  Always Ultra Day Sanitary Towels Normal (Size ...  20240122
#
#                category  own_brand  previous_price  price_change  \
# 460062  health_products      False             3.5           0.0
# 452062  health_products      False             3.5           0.0
# 447885  health_products      False             3.5           0.0
# 443000  health_products      False             3.5           0.0
# 438363  health_products      False             3.5           0.0
# 433144  health_products      False             3.5           0.0
# 427865  health_products      False             3.5           0.0
# 422294  health_products      False             3.5           0.0
# 403510  health_products      False             3.5           0.0
# 399915  health_products      False             3.5           0.0
#
#         percent_change  median_price_unit  percent_difference
# 460062             0.0               0.11                 0.0
# 452062             0.0               0.11                 0.0
# 447885             0.0               0.11                 0.0
# 443000             0.0               0.11                 0.0
# 438363             0.0               0.11                 0.0
# 433144             0.0               0.11                 0.0
# 427865             0.0               0.11                 0.0
# 422294             0.0               0.11                 0.0
# 403510             0.0               0.11                 0.0
# 399915             0.0               0.11                 0.0

# %%
df.nlargest(10, "prices_unit_(£)")
# Out:
#        supermarket  prices_(£)  prices_unit_(£) unit  \
# 455789        Aldi        1.99             99.5    l
# 454572        Aldi        1.99             99.5    l
# 449417        Aldi        1.99             99.5    l
# 444477        Aldi        1.99             99.5    l
# 439841        Aldi        1.99             99.5    l
# 435134        Aldi        1.99             99.5    l
# 429722        Aldi        1.99             99.5    l
# 425406        Aldi        1.99             99.5    l
# 420385        Aldi        1.99             99.5    l
# 410914        Aldi        1.99             99.5    l
#
#                                                     names      date  \
# 455789  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240110
# 454572  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240111
# 449417  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240112
# 444477  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240113
# 439841  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240114
# 435134  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240115
# 429722  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240116
# 425406  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240117
# 420385  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240118
# 410914  Scentcerity Fresh Linen And Freesia Plug-in Re...  20240119
#
#          category  own_brand  previous_price  price_change  percent_change  \
# 455789  household      False            1.99           0.0             0.0
# 454572  household      False            1.99           0.0             0.0
# 449417  household      False            1.99           0.0             0.0
# 444477  household      False            1.99           0.0             0.0
# 439841  household      False            1.99           0.0             0.0
# 435134  household      False            1.99           0.0             0.0
# 429722  household      False            1.99           0.0             0.0
# 425406  household      False            1.99           0.0             0.0
# 420385  household      False            1.99           0.0             0.0
# 410914  household      False            1.99           0.0             0.0
#
#         median_price_unit  percent_difference
# 455789               99.5                 0.0
# 454572               99.5                 0.0
# 449417               99.5                 0.0
# 444477               99.5                 0.0
# 439841               99.5                 0.0
# 435134               99.5                 0.0
# 429722               99.5                 0.0
# 425406               99.5                 0.0
# 420385               99.5                 0.0
# 410914               99.5                 0.0

# %%
 # Random results test

temp_result = df.iloc[np.random.default_rng().choice(len(df), size=5, replace=False)]

temp_result
# Out:
#        supermarket  prices_(£)  prices_unit_(£)  unit  \
# 146660        Aldi        0.59             5.90    kg
# 407500        Aldi        0.89             0.89  unit
# 437662        Aldi        0.95             1.30    kg
# 170637        Aldi        3.99            21.57    kg
# 161467        Aldi        2.19             8.76    kg
#
#                                                     names      date  \
# 146660           Mamia Summer Fruits Jelly Pouches 4x100g  20240316
# 407500                     Nature's Pick Pomegranate Each  20240120
# 437662       Brooklea Berry Medley Low Fat Yogurts 6x125g  20240114
# 170637  The Fishmonger Hot Smoked Sweet Chilli Salmon ...  20240310
# 161467   Specially Selected Tomato & Burrata Ravioli 250g  20240312
#
#              category  own_brand  previous_price  price_change  \
# 146660  baby_products      False            0.59           0.0
# 407500     fresh_food      False            0.89           0.0
# 437662     fresh_food      False            0.95           0.0
# 170637     fresh_food      False            3.99           0.0
# 161467     fresh_food       True            2.19           0.0
#
#         percent_change  median_price_unit  percent_difference
# 146660             0.0               5.90            0.000000
# 407500             0.0               0.95            6.315789
# 437662             0.0               1.20            8.333333
# 170637             0.0              21.57            0.000000
# 161467             0.0               8.76            0.000000

# %% [markdown]
# REMOVING CATEGORY

# %%
final_df = df.drop(df[df['category'] == 'free-from'].index)

print(f"Original rows: {len(df)}")
print(f"Final rows: {len(final_df)}")
print(f"Rows removed: {len(df) - len(final_df)}")

# %% [markdown]
# CLEANUP

# %%
 # Renaming column
final_df = final_df.rename(columns={
    'names': 'product',
    'prices_(£)': 'prices',
    'prices_unit_(£)': 'prices_unit'
})

# %%
 # Dropping unecessary columns
final_df = final_df.drop(columns=['previous_price', 'price_change', 'percent_change', 'median_price_unit','percent_difference'])

# %%
 # Organizing Column order
final_df = final_df[['category', 'prices', 'prices_unit', 'unit', 'product', 'date', 'own_brand', 'supermarket']]

# %%
 # Quick column check
print(final_df.columns)
# Out:
# Index(['category', 'prices', 'prices_unit', 'unit', 'product', 'date',
#        'own_brand', 'supermarket'],
#       dtype='str')

# %% [markdown]
# CONVERT TO CSV

# %%
final_df.to_csv("Aldi_clean.csv", index=False)

# %%
 # Final check, vs_code database loaded properly
final_df.shape
# Out:
# (435655, 8)
